# %%
import numpy as np
import matplotlib.pylab as plt
import matplotlib
import math
# %matplotlib inline
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
# Question 1

x = np.arange(1.920, 2.080, .001)

px = x**9 - (18*x**8) + (144*x**7) - (672*x**6) + (2016*x**5) - (4032*x**4) + (5376*x**3) - (4608*x**2) + (2304*x) - 512

px_1 = (x-2)**9

plt.plot(x, px, label = "Factored Form", color = "blue")
plt.plot(x, px_1, label = "Unfactored Form", color = "red")
plt.title("Plot of p(x)")
plt.xlabel('x')
plt.ylabel('p(x)')
plt.legend()
plt.grid(True)
plt.savefig("Q1 i.png")
plt.show()

# %%
# Question 2

r1 = 55.982

r11 = (56 + np.sqrt(56**2 - 4))/2

er1 = np.abs(r1 - r11)/np.abs(r11)
print(er1)

r2 = 0.018

r22 = (56 - np.sqrt(56**2 - 4))/2

er2 = np.abs(r2 - r22)/np.abs(r22)
print(er2)
# Out:
# 2.450054131621939e-06
# 0.007678468866698233
